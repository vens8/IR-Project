# %%
import streamlit as st
import requests
import time
import moviepy.editor as mp
from io import StringIO
from PIL import Image
import os 
import os
import random
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
import bs4
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
nltk.download('stopwords')
import heapq
import operator
import math
import pickle

def change_text(data):
    data=data.lower()
    data=nltk.word_tokenize(data)
    english_stopwords = stopwords.words()
    tokens_wo_stopwords = [t for t in data if t not in english_stopwords]
    data=tokens_wo_stopwords
    lst=[]
    for i in data:
        if(i.isalpha()):
            lst.append(i)   
    data= lst
    return " ".join(data)    

def analyse_text():
    file_name=""
    data=""
    for file in os.listdir(os.getcwd()):
        if file.endswith(".txt"):
            file_name=file
            # file_name=file_name+".txt"
            # print(file_name)
            with open(file_name, 'r') as file:
                data = file.read() 
    print(data)
    final_data=change_text(data)
    word_cloud = WordCloud(collocations = False, background_color = 'white').generate(final_data)
    # Display the generated Word Cloud
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
analyse_text()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sumit
# [nltk_data]     Soni\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Is you, over you towards the unique that is you. But the world around you is doing its best day and night to make you just everybody else. Now, the question is whether you want to be you or everybody else. You. You want to be you, not everybody else. Now, if the question being like everybody else is convenient at the first glance but not satisfying in the long.

# %%
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import os
file_name=""
for file in os.listdir(os.getcwd()):
    if file.endswith(".wav"):
        file_name=file
data, sampling_rate=librosa.load(file_name)
plt.figure(figsize=(15,5))
librosa.display.waveshow(data,sr=sampling_rate)
ipd.Audio(file_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14088\2229151557.py in <module>
#       1 import IPython.display as ipd
# ----> 2 import librosa
#       3 import librosa.display
#       4 import matplotlib.pyplot as plt
#       5 import os
#
# ModuleNotFoundError: No module named 'librosa'
